# %% [markdown]
# # **Clustering and Tree with Reduced Aligned Brains**

# %% [markdown]
# *k=25*

# %%
import pyvista as pv
import os

data_path = 'data/k25-aligned'

plotter = pv.Plotter(shape=(8, 9), window_size=(1000, 1200))
i = 0

for root, dirs, files in os.walk(data_path):
    for folder in sorted(dirs):
        

        mesh = pv.read(os.path.join(root, folder, 'reconstructed_aligned.stl'))
        

        row = i // 9
        col = i % 9
        plotter.subplot(row, col)
        plotter.add_text(folder[:8], font_size=9)
        plotter.add_mesh(mesh, opacity=1, color='lightslateblue')
        i += 1

        plotter.camera_position = [
                        (-1, 0, 0),  
                        (0, 0, 0),   
                        (0, 0, 1)    
        ]
        plotter.reset_camera()

plotter.show()
# Out:
# Widget(value='<iframe src="http://localhost:36531/index.html?ui=P_0x7fa7685910a0_0&reconnect=auto" class="pyvi…

# %%
import os
import numpy as np
import h5py
import pyvista as pv
import trimesh
from matplotlib import pyplot as plt

# %run '../toothForge/src/Graph.py'

data_path = 'data/k25-aligned'

plotter = pv.Plotter(shape=(8, 9), window_size=(1000, 1200))
i = 0

for root, dirs, files in os.walk(data_path):
    for folder in sorted(dirs):
        
        stl_path = os.path.join(root, folder, 'reconstructed_aligned.stl')
        tmesh = trimesh.load(stl_path, force='mesh')
        graph = Graph(tmesh, k=25)
        _, evecs, _, _ = graph.apply_decomposition()

        jet_cmap = plt.get_cmap('jet')

        eigenmodes_m_sliced = evecs[:, 0]
        eigenmodes_m_n = (eigenmodes_m_sliced - np.min(eigenmodes_m_sliced)) / (np.max(eigenmodes_m_sliced) - np.min(eigenmodes_m_sliced))
        clrs_m = (jet_cmap(eigenmodes_m_n)[:, :3] * 255).astype(np.uint8)
        
        row = i // 9
        col = i % 9
        plotter.subplot(row, col)
        plotter.add_text(folder[:8], font_size=9)
        plotter.add_mesh(tmesh, scalars=clrs_m, rgb=True)
        
        i += 1

        plotter.camera_position = [
                            (-1, 0, 0), 
                            (0, 0, 0), 
                            (0, 0, 1)   
        ]
        plotter.reset_camera()


plotter.show()
# Out:
# /home/usagers/u139043/Documents/Imaging/.env/lib64/python3.9/site-packages/networkx/utils/backends.py:135: RuntimeWarning: networkx backend defined more than once: nx-loopback
#   backends.update(_get_backends("networkx.backends"))
# Widget(value='<iframe src="http://localhost:40257/index.html?ui=P_0x7f8653390640_1&reconnect=auto" class="pyvi…

# %% [markdown]
# ![screenshot(64).png](attachment:388bf714-49ab-4322-bb84-85dbd00f353d.png)

# %%
# photos of other eigenvecs

# %%
import os
import numpy as np
import h5py
import pyvista as pv
import trimesh
from matplotlib import pyplot as plt

# %run '../src/Graph.py'

data_path = 'data/k25-aligned'

plotter = pv.Plotter(shape=(8, 9), window_size=(1000, 1200))
i = 0

for root, dirs, files in os.walk(data_path):
    for folder in sorted(dirs):
        
        stl_path = os.path.join(root, folder, 'reconstructed_aligned.stl')
        tmesh = trimesh.load(stl_path, force='mesh')
        graph = Graph(tmesh, k=25)
        _, evecs, _, _ = graph.apply_decomposition()

        jet_cmap = plt.get_cmap('jet')

        eigenmodes_m_sliced = evecs[:, 9]
        eigenmodes_m_n = (eigenmodes_m_sliced - np.min(eigenmodes_m_sliced)) / (np.max(eigenmodes_m_sliced) - np.min(eigenmodes_m_sliced))
        clrs_m = (jet_cmap(eigenmodes_m_n)[:, :3] * 255).astype(np.uint8)
        
        row = i // 9
        col = i % 9
        plotter.subplot(row, col)
        plotter.add_text(folder[:8], font_size=9)
        plotter.add_mesh(tmesh, scalars=clrs_m, rgb=True)
        
        i += 1

        plotter.camera_position = [
                            (-1, 0, 0), 
                            (0, 0, 0), 
                            (0, 0, 1)   
        ]
        plotter.reset_camera()


plotter.show()
# Out:
# Widget(value='<iframe src="http://localhost:39617/index.html?ui=P_0x7fae119596d0_2&reconnect=auto" class="pyvi…

# %% [markdown]
# ![screenshot(65).png](attachment:8652221b-86df-473f-b498-5f99dd1f319c.png)

# %%
import os
import numpy as np
import h5py
import pyvista as pv
import trimesh
from matplotlib import pyplot as plt

# %run '../src/Graph.py'

data_path = 'data/k25-aligned'

plotter = pv.Plotter(shape=(8, 9), window_size=(1000, 1200))
i = 0

for root, dirs, files in os.walk(data_path):
    for folder in sorted(dirs):
        
        stl_path = os.path.join(root, folder, 'reconstructed_aligned.stl')
        tmesh = trimesh.load(stl_path, force='mesh')
        graph = Graph(tmesh, k=25)
        _, evecs, _, _ = graph.apply_decomposition()

        jet_cmap = plt.get_cmap('jet')

        eigenmodes_m_sliced = evecs[:, 19]
        eigenmodes_m_n = (eigenmodes_m_sliced - np.min(eigenmodes_m_sliced)) / (np.max(eigenmodes_m_sliced) - np.min(eigenmodes_m_sliced))
        clrs_m = (jet_cmap(eigenmodes_m_n)[:, :3] * 255).astype(np.uint8)
        
        row = i // 9
        col = i % 9
        plotter.subplot(row, col)
        plotter.add_text(folder[:8], font_size=9)
        plotter.add_mesh(tmesh, scalars=clrs_m, rgb=True)
        
        i += 1

        plotter.camera_position = [
                            (-1, 0, 0), 
                            (0, 0, 0), 
                            (0, 0, 1)   
        ]
        plotter.reset_camera()


plotter.show()
# Out:
# Widget(value='<iframe src="http://localhost:39617/index.html?ui=P_0x7fad834b3280_4&reconnect=auto" class="pyvi…

# %% [markdown]
# ![screenshot(66).png](attachment:7d9c93b5-eb0c-4df9-a67d-b88cc7f0541b.png)

# %%
import os
import numpy as np
import h5py
import pyvista as pv
import trimesh
from matplotlib import pyplot as plt

# %run '../src/Graph.py'

data_path = 'data/k25-aligned'

plotter = pv.Plotter(shape=(8, 9), window_size=(1000, 1200))
i = 0

for root, dirs, files in os.walk(data_path):
    for folder in sorted(dirs):
        
        stl_path = os.path.join(root, folder, 'reconstructed_aligned.stl')
        tmesh = trimesh.load(stl_path, force='mesh')
        graph = Graph(tmesh, k=25)
        _, evecs, _, _ = graph.apply_decomposition()

        jet_cmap = plt.get_cmap('jet')

        eigenmodes_m_sliced = evecs[:, 24]
        eigenmodes_m_n = (eigenmodes_m_sliced - np.min(eigenmodes_m_sliced)) / (np.max(eigenmodes_m_sliced) - np.min(eigenmodes_m_sliced))
        clrs_m = (jet_cmap(eigenmodes_m_n)[:, :3] * 255).astype(np.uint8)
        
        row = i // 9
        col = i % 9
        plotter.subplot(row, col)
        plotter.add_text(folder[:8], font_size=9)
        plotter.add_mesh(tmesh, scalars=clrs_m, rgb=True)
        
        i += 1

        plotter.camera_position = [
                            (-1, 0, 0), 
                            (0, 0, 0), 
                            (0, 0, 1)   
        ]
        plotter.reset_camera()


plotter.show()
# Out:
# Widget(value='<iframe src="http://localhost:39617/index.html?ui=P_0x7fad68dfcbb0_5&reconnect=auto" class="pyvi…

# %% [markdown]
# ![screenshot(67).png](attachment:b4a68a88-841d-4b25-a259-3218638f5446.png)

# %% [markdown]
# ### Exporting mesh pictures

# %%
import pyvista as pv
import os

data_path = 'data/k25-aligned'

for root, dirs, files in os.walk(data_path):
    for folder in sorted(dirs):
        
        mesh = pv.read(os.path.join(root, folder, 'reconstructed_aligned.stl'))
        plotter = pv.Plotter(off_screen=True)
        plotter.add_mesh(mesh, color='mediumaquamarine')

        plotter.camera_position = [
                        (-1, 0, 0),  
                        (0, 0, 0),   
                        (0, 0, 1)    
        ]
        plotter.reset_camera()
        
        plotter.screenshot(f"{os.path.join(data_path, folder)}/thumbnail.png", transparent_background=True)
        plotter.close()

# %% [markdown]
# ### Coefficients and PCA

# %%
import h5py
data_path = 'data/k25-aligned'
import os 

coefficients = [] # k x 3
names = []
thumbnails = []

for root, dirs, files in os.walk(data_path):
    for folder in dirs:
        c_file = h5py.File(os.path.join(root, folder, 'spec_coeff.h5'))
        c = c_file['c'][()]
        
        if folder != 'template-sub-001_species-Cercopithecus+cephus_hemi-L':
            r_file = h5py.File(os.path.join(root, folder, 'spec_rotation.h5'))
            r = r_file['R'][()]
            c = r @ c
            
        coefficients.append(c)
        names.append(folder)
        thumbnails.append(os.path.join(root, folder, 'thumbnail.png'))

# %% [markdown]
# ***2D***

# %%
import numpy as np
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler

# Flatten coefficient matrices
flattened_c = [mat.flatten() for mat in coefficients] # k x n
X = np.array(flattened_c)

# Normalize
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

pca = PCA(n_components=2)
X_flattened = pca.fit_transform(X)

X_flattened
# Out:
# array([[ 9.13284133e+00,  2.12321449e+00],
#        [ 1.58252296e+01,  1.17431406e+01],
#        [-2.52523338e+01, -1.23168020e+00],
#        [-6.23784455e+00,  1.28540765e-01],
#        [-3.41464723e+01, -5.21610013e-01],
#        [ 1.11108113e+01,  4.58870962e+00],
#        [ 1.97109933e+01,  7.22217687e+00],
#        [ 8.71936438e+00,  1.40386702e+01],
#        [-9.25867288e+00, -9.05833348e+00],
#        [ 1.00309250e+01,  3.07925109e+00],
#        [ 1.12323915e+01, -1.18918546e+01],
#        [ 8.52866244e+00, -3.48801840e+00],
#        [-4.05289340e+00, -8.90971500e+00],
#        [-1.88698939e+01,  3.41264392e-01],
#        [ 5.52985534e+00, -1.79175966e+01],
#        [-2.78778772e+00, -4.99379667e+00],
#        [-8.51909821e+00,  1.12567856e+01],
#        [-1.44150491e+00, -1.72013981e+00],
#        [ 1.09222340e+01,  1.37376688e+01],
#        [-4.98845360e+00, -4.61559729e-01],
#        [ 1.92571075e+01, -4.34999882e+00],
#        [ 8.47310599e+00,  1.47674753e+00],
# ...

# %%
from matplotlib import pyplot as plt

#%matplotlib widget

x = X_flattened[:, 0]
y = X_flattened[:, 1]
#z = X_flattened[:, 2]

fig = plt.figure(figsize=(10, 8))

plt.plot(x, y, color="green", marker='o', linestyle='')

plt.title("2D coefficients")
plt.xlabel("x")
plt.ylabel("y")

plt.grid(True)
plt.tight_layout()
plt.show()

# %%
from matplotlib import pyplot as plt
from matplotlib.offsetbox import OffsetImage, AnnotationBbox
import matplotlib.image as mpimg

#%matplotlib widget

x = X_flattened[:, 0]
y = X_flattened[:, 1]

fig, ax = plt.subplots(figsize=(10, 8))

plt.plot(x, y, color="red", marker='o', linestyle='')

ax.set_title("2D coefficients")
ax.set_xlabel("x")
ax.set_ylabel("y")

for xi, yi, thumbnail in zip(x, y, thumbnails):
    img = mpimg.imread(thumbnail)
    imagebox = OffsetImage(img, zoom=0.06)
    ab = AnnotationBbox(imagebox, (xi, yi), frameon=False)
    ax.add_artist(ab)
    

ax.grid(True)
plt.tight_layout()
plt.savefig("nonorm.png", dpi='figure', bbox_inches='tight')
plt.show()

# %% [markdown]
# <table>
#   <tr>
#     <td><p>Without normalization</p>
#         <img src="attachment:83bfae6e-52f2-46d5-9629-64b9a7109a25.png" width="600"/></td>
#     <td><p>With normalization</p>
#         <img src="attachment:b1ed96e4-26a7-4904-9948-3690e0ae96fe.png" width="600"/></td>
#   </tr>
# </table>

# %% [markdown]
# ## Hierarchical Clustering Dendrogram with Normalized Coefficients

# %%
from scipy.cluster.hierarchy import dendrogram
from sklearn.cluster import AgglomerativeClustering

def plot_dendrogram(model):
    # Create linkage matrix and then plot the dendrogram

    # create the counts of samples under each node
    counts = np.zeros(model.children_.shape[0])
    n_samples = len(model.labels_)
    for i, merge in enumerate(model.children_):
        current_count = 0
        for child_idx in merge:
            if child_idx < n_samples:
                current_count += 1  # leaf node
            else:
                current_count += counts[child_idx - n_samples]
        counts[i] = current_count

    linkage_matrix = np.column_stack(
        [model.children_, model.distances_, counts]
    ).astype(float)

    # Plot the dendrogram
    dendrogram(linkage_matrix)

    
model = AgglomerativeClustering(distance_threshold=0, n_clusters=None, linkage="average")
model = model.fit(X_scaled)
plt.title("Hierarchical Clustering Dendogram of Coefficients")

# plot the levels
plot_dendrogram(model)
plt.xlabel("index of point")
plt.show()

# %%
from scipy.cluster.hierarchy import dendrogram
from sklearn.cluster import AgglomerativeClustering
import matplotlib.pyplot as plt 

def plot_dendrogram(model):
    # Create linkage matrix and then plot the dendrogram

    # create the counts of samples under each node
    counts = np.zeros(model.children_.shape[0])
    n_samples = len(model.labels_)
    for i, merge in enumerate(model.children_):
        current_count = 0
        for child_idx in merge:
            if child_idx < n_samples:
                current_count += 1  # leaf node
            else:
                current_count += counts[child_idx - n_samples]
        counts[i] = current_count

    linkage_matrix = np.column_stack(
        [model.children_, model.distances_, counts]
    ).astype(float)

    # Plot the dendrogram
    dendrogram(linkage_matrix, labels=names, orientation="left", leaf_font_size=10)

    
model = AgglomerativeClustering(distance_threshold=0, n_clusters=None, linkage="average")
model = model.fit(X_scaled)
plt.figure(figsize=(15, 15))
plt.title("Hierarchical Clustering Dendogram of Coefficients")

# plot the levels
plot_dendrogram(model)
plt.xlabel("species")
plt.savefig("ClusterDendrogram.png", dpi='figure', bbox_inches='tight')

plt.show()

# %%
# Circular tree
# Installing https://github.com/koonimaru/radialtree
import radialtree as rt
import matplotlib.pyplot as plt

plt.rcParams['font.family'] = 'DejaVu Sans'

counts = np.zeros(model.children_.shape[0])
n_samples = len(model.labels_)
for i, merge in enumerate(model.children_):
    current_count = 0
    for child_idx in merge:
        if child_idx < n_samples:
            current_count += 1  # leaf node
        else:
            current_count += counts[child_idx - n_samples]
    counts[i] = current_count

linkage_matrix = np.column_stack([model.children_, model.distances_, counts]).astype(float)

model = AgglomerativeClustering(distance_threshold=0, n_clusters=None, linkage="average")
model = model.fit(X_scaled)

d = dendrogram(linkage_matrix, labels=names, no_plot=True, leaf_font_size=10)

fig, ax = plt.subplots(figsize=(9,9))
ax = rt.radialTreee(d, pallete="gist_rainbow")

# %%
# change label names
species_names = []

for name in names:
    species_part = name.split("species-")[1]
    species_part = species_part.split("_hemi-L")[0]
    species_part = species_part.replace("+", " ")
    species_names.append(species_part)

# %%
species_names
# Out:
# ['Tamias striatus',
#  'Fukomys mechowi',
#  'Callithrix geoffroyi',
#  'Saguinus imperator',
#  'Semnopithecus entellus',
#  'Aplodontia rufa',
#  'Mus musculus',
#  'Thomomys talpoides',
#  'Cercopithecus cephus',
#  'Daubentonia madagascariensis',
#  'Gorilla gorilla',
#  'Microcebus murinus',
#  'Lagothrix lagotricha',
#  'Cebus capucinus',
#  'Pan troglodytes',
#  'Macaca fascicularis',
#  'Pongo pygmaeus',
#  'Macaca mulatta',
#  'Mus musculus',
#  'Sciurus vulgaris',
#  'Heterocephalus glaber',
#  'Nycticebus bengalensis',
#  'Georychus capensis',
#  'Heliophobius argenteocinereus',
#  'Cebuella pygmaea',
#  'Eulemur coronatus',
#  'Aotus trivirgatus',
#  'Eulemur mongoz',
#  'Mirza coquereli',
#  'Erethizon dorsatum',
#  'Homo sapiens',
#  'Macaca nigra',
#  'Saguinus midas',
#  'Ondatra zibethicus',
#  'Bathyergus suillus',
#  'Aotus lemurinus',
#  'Cercopithecus mitis',
#  'Macaca sylvanus',
#  'Cercocebus atys',
#  'Saimiri boliviensis',
#  'Papio anubis',
# ...

# %%
# Circular tree
# Installing https://github.com/koonimaru/radialtree
import radialtree as rt
import matplotlib.pyplot as plt

plt.rcParams['font.family'] = 'DejaVu Sans'

counts = np.zeros(model.children_.shape[0])
n_samples = len(model.labels_)
for i, merge in enumerate(model.children_):
    current_count = 0
    for child_idx in merge:
        if child_idx < n_samples:
            current_count += 1  # leaf node
        else:
            current_count += counts[child_idx - n_samples]
    counts[i] = current_count

linkage_matrix = np.column_stack([model.children_, model.distances_, counts]).astype(float)

model = AgglomerativeClustering(distance_threshold=0, n_clusters=None, linkage="average")
model = model.fit(X_scaled)

d = dendrogram(linkage_matrix, labels=species_names, no_plot=True, leaf_font_size=10)

fig, ax = plt.subplots(figsize=(9,9))
ax = rt.radialTreee(d, pallete="tab10_r")
1
for line in ax.lines:
    line.set_linewidth(1.2)

fig.savefig("RadialTree.png", dpi='figure', bbox_inches='tight')

# %%
names
# Out:
# ['sub-090_species-Tamias+striatus_hemi-L',
#  'sub-066_species-Fukomys+mechowi_hemi-L',
#  'sub-070_species-Callithrix+geoffroyi_hemi-L',
#  'sub-082_species-Saguinus+imperator_hemi-L',
#  'sub-031_species-Semnopithecus+entellus_hemi-L',
#  'sub-046_species-Aplodontia+rufa_hemi-L',
#  'sub-043ABA_species-Mus+musculus_hemi-L',
#  'sub-039_species-Thomomys+talpoides_hemi-L',
#  'template-sub-001_species-Cercopithecus+cephus_hemi-L',
#  'sub-003_species-Daubentonia+madagascariensis_hemi-L',
#  'sub-019_species-Gorilla+gorilla_hemi-L',
#  'sub-007_species-Microcebus+murinus_hemi-L',
#  'sub-011_species-Lagothrix+lagotricha_hemi-L',
#  'sub-015_species-Cebus+capucinus_hemi-L',
#  'sub-023_species-Pan+troglodytes_hemi-L',
#  'sub-027_species-Macaca+fascicularis_hemi-L',
#  'sub-024_species-Pongo+pygmaeus_hemi-L',
#  'sub-028_species-Macaca+mulatta_hemi-L',
#  'sub-043_species-Mus+musculus_hemi-L',
#  'sub-047_species-Sciurus+vulgaris_hemi-L',
# ...

# %%
# Circular tree
# Installing https://github.com/koonimaru/radialtree
import radialtree as rt
import matplotlib.pyplot as plt
from matplotlib.offsetbox import OffsetImage, AnnotationBbox
import matplotlib.image as mpimg
import os
import numpy as np

plt.rcParams['font.family'] = 'DejaVu Sans'

counts = np.zeros(model.children_.shape[0])
n_samples = len(model.labels_)
for i, merge in enumerate(model.children_):
    current_count = 0
    for child_idx in merge:
        if child_idx < n_samples:
            current_count += 1  # leaf node
        else:
            current_count += counts[child_idx - n_samples]
    counts[i] = current_count

linkage_matrix = np.column_stack([model.children_, model.distances_, counts]).astype(float)

model = AgglomerativeClustering(distance_threshold=0, n_clusters=None, linkage="average")
model = model.fit(X_scaled)

d = dendrogram(linkage_matrix, labels=species_names, no_plot=True, leaf_font_size=10)

fig, ax = plt.subplots(figsize=(9,9))
ax = rt.radialTreee(d, pallete="tab10_r")

for line in ax.lines:
    line.set_linewidth(1.5)

i = 0
for text in ax.texts:
    img_arr = mpimg.imread(os.path.join("../toothForge/data/laplace/k25-aligned/", names[i], "thumbnail.png"))
    imagebox = OffsetImage(img_arr, zoom=0.07)

    # Convert from cartesian to polar coords
    x, y = text.get_position()[0], text.get_position()[1]    
    r = np.sqrt(x**2 + y**2)
    theta = np.arctan2(y, x)

    # Image offset
    r_img = r + 0.5

    # Polar to cartesian
    x_img = r_img * np.cos(theta)
    y_img = r_img * np.sin(theta)
    
    ab = AnnotationBbox(
        imagebox,
        xy = (text.get_position()[0], text.get_position()[1]),
        xybox = (x_img, y_img),
        frameon=False,
    )
    ax.add_artist(ab)
    i += 1


fig.savefig("RadialTreeThumbnails.png", bbox_inches='tight')
