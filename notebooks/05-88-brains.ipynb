# %% [markdown]
# # 88 Aligned Brains

# %%
import pyvista as pv
import os

data_path = '../toothForge/data/laplace/88-brainsc'

plotter = pv.Plotter(shape=(10, 9), window_size=(1000, 1200))
i = 0

for root, dirs, files in os.walk(data_path):
    for folder in sorted(dirs):
        

        mesh = pv.read(os.path.join(root, folder, 'reconstructed_aligned.stl'))
        

        row = i // 10
        col = i % 9
        plotter.subplot(row, col)
        plotter.add_mesh(mesh, opacity=1, color='lightgreen')
        i += 1

        plotter.camera_position = [
                        (-1, 0, 0),  
                        (0, 0, 0),   
                        (0, 0, 1)    
        ]
        plotter.reset_camera()

plotter.show()
# Out:
# Widget(value='<iframe src="http://localhost:44477/index.html?ui=P_0x7fd9c979d430_33&reconnect=auto" class="pyv…

# %% [markdown]
# ## Eigenvector 1

# %%
# %run '../toothForge/src/Graph.py'

# %%
import os
import numpy as np
import h5py
import pyvista as pv
import trimesh
from matplotlib import pyplot as plt

data_path = '../toothForge/data/laplace/88-brains'




plotter = pv.Plotter(shape=(10, 9), window_size=(1000, 1200))
i = 0

for root, dirs, files in os.walk(data_path):
    for folder in sorted(dirs):

        stl_path = os.path.join(root, folder, 'mesh.stl')
        tmesh = trimesh.load(stl_path, force='mesh')
        evecs = 

        jet_cmap = plt.get_cmap('jet')

        eigenmodes_m_sliced = evecs[:, 0]
        eigenmodes_m_n = (eigenmodes_m_sliced - np.min(eigenmodes_m_sliced)) / (np.max(eigenmodes_m_sliced) - np.min(eigenmodes_m_sliced))
        clrs_m = (jet_cmap(eigenmodes_m_n)[:, :3] * 255).astype(np.uint8)
        
        row = i // 9
        col = i % 9
        plotter.subplot(row, col)
        plotter.add_mesh(tmesh, scalars=clrs_m, rgb=True)
        
        i += 1
        if i >= 90:
            break

        plotter.camera_position = [
                            (-1, 0, 0), 
                            (0, 0, 0), 
                            (0, 0, 1)   
        ]
        plotter.reset_camera()


plotter.show()
# Out:
#   Cell In[39], line 21
#     evecs =
#             ^
# SyntaxError: invalid syntax

# %% [markdown]
# ![screenshot(35).png](attachment:2ace37a6-4959-4166-ae1d-82ded69227c8.png)

# %%
import os
import numpy as np
import h5py
import pyvista as pv
import trimesh
from matplotlib import pyplot as plt

data_path = '../toothForge/data/laplace/88-brains'

plotter = pv.Plotter(shape=(10, 9), window_size=(1000, 1200))
i = 0

for root, dirs, files in os.walk(data_path):
    for folder in sorted(dirs):
        
        stl_path = os.path.join(root, folder, 'reconstructed_aligned.stl')
        tmesh = trimesh.load(stl_path, force='mesh')
        graph = Graph(tmesh, k=100)
        _, evecs, _, _ = graph.apply_decomposition()

        jet_cmap = plt.get_cmap('jet')

        eigenmodes_m_sliced = evecs[:, 0]
        eigenmodes_m_n = (eigenmodes_m_sliced - np.min(eigenmodes_m_sliced)) / (np.max(eigenmodes_m_sliced) - np.min(eigenmodes_m_sliced))
        clrs_m = (jet_cmap(eigenmodes_m_n)[:, :3] * 255).astype(np.uint8)
        
        row = i // 9
        col = i % 9
        plotter.subplot(row, col)
        plotter.add_mesh(tmesh, scalars=clrs_m, rgb=True)
        
        i += 1

        plotter.camera_position = [
                            (-1, 0, 0), 
                            (0, 0, 0), 
                            (0, 0, 1)   
        ]
        plotter.reset_camera()


plotter.show()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 18
#      16 stl_path = os.path.join(root, folder, 'reconstructed_aligned.stl')
#      17 tmesh = trimesh.load(stl_path, force='mesh')
# ---> 18 graph = Graph(tmesh, k=100)
#      19 _, evecs, _, _ = graph.apply_decomposition()
#      21 jet_cmap = plt.get_cmap('jet')
#
# File /home/usagers/u139043/Documents/Imaging/toothForge/src/Graph.py:27, in Graph.__init__(self, mesh_tri, k, L_approx_type)
#      25 # Assign matrices that will be used for laplacian and eigen decomposition.
#      26 self.L, self.M = self.get_laplacian()  # M is the max matrix
# ---> 27 self.eig_vals, self.eig_vecs, self.eig_vecs_inv, self.X = self.apply_decomposition()
#
# File /home/usagers/u139043/Documents/Imaging/toothForge/src/Graph.py:37, in Graph.apply_decomposition(self)
#      35 def apply_decomposition(self):
#      36     #print(f'Computing top {self.k} eigenvectors and eigenvalues...')
# ---> 37     eig_vals, eig_vecs = eigs(self.L, k=self.k, sigma=1e-10, which='LR')
#      39     eig_vals = np.real(eig_vals)
#      40     eig_vecs = np.real(eig_vecs)
#
# File /home/usagers/u139043/Documents/Imaging/.env/lib64/python3.9/site-packages/scipy/sparse/linalg/_eigen/arpack/arpack.py:1355, in eigs(A, k, M, sigma, which, v0, ncv, maxiter, tol, return_eigenvectors, Minv, OPinv, OPpart)
#    1353 with _ARPACK_LOCK:
#    1354     while not params.converged:
# -> 1355         params.iterate()
#    1357     return params.extract(return_eigenvectors)
#
# File /home/usagers/u139043/Documents/Imaging/.env/lib64/python3.9/site-packages/scipy/sparse/linalg/_eigen/arpack/arpack.py:723, in _UnsymmetricArpackParams.iterate(self)
#     721 def iterate(self):
#     722     if self.tp in 'fd':
# --> 723         results = self._arpack_solver(self.ido, self.bmat, self.which, self.k,
#     724                                       self.tol, self.resid, self.v, self.iparam,
#     725                                       self.ipntr, self.workd, self.workl, self.info)
#     726         self.ido, self.tol, self.resid, self.v, \
#     727             self.iparam, self.ipntr, self.info = results
#     729     else:
#
# KeyboardInterrupt:

# %%
import os
import numpy as np
import h5py
import pyvista as pv
import trimesh
from matplotlib import pyplot as plt

# %run '../toothForge/src/Graph.py'

data_path = '../toothForge/data/laplace/88-brains'

plotter = pv.Plotter(shape=(10, 9), window_size=(1000, 1200))
i = 0

for root, dirs, files in os.walk(data_path):
    for folder in sorted(dirs):
        
        stl_path = os.path.join(root, folder, 'reconstructed_aligned.stl')
        tmesh = trimesh.load(stl_path, force='mesh')
        graph = Graph(tmesh, k=100)
        _, evecs, _, _ = graph.apply_decomposition()

        jet_cmap = plt.get_cmap('jet')

        eigenmodes_m_sliced = evecs[:, 0]
        eigenmodes_m_n = (eigenmodes_m_sliced - np.min(eigenmodes_m_sliced)) / (np.max(eigenmodes_m_sliced) - np.min(eigenmodes_m_sliced))
        clrs_m = (jet_cmap(eigenmodes_m_n)[:, :3] * 255).astype(np.uint8)
        
        row = i // 9
        col = i % 9
        plotter.subplot(row, col)
        plotter.add_mesh(tmesh, scalars=clrs_m, rgb=True)
        
        i += 1
        if i >= 90:
            break

        plotter.camera_position = [
                            (-1, 0, 0), 
                            (0, 0, 0), 
                            (0, 0, 1)   
        ]
        plotter.reset_camera()


plotter.show()
# Out:
# Widget(value='<iframe src="http://localhost:35307/index.html?ui=P_0x7fd09cfd3e50_29&reconnect=auto" class="pyv…

# %% [markdown]
# ![screenshot(37).png](attachment:53495cce-25c1-41dd-bf32-d7f9d6e5bc26.png)

# %%
import os
import numpy as np
import h5py
import pyvista as pv
import trimesh
from matplotlib import pyplot as plt

data_path = '../toothForge/data/laplace/88-brainsc'

plotter = pv.Plotter(shape=(10, 9), window_size=(1000, 1200))
i = 0

for root, dirs, files in os.walk(data_path):
    for folder in sorted(dirs):
        
        stl_path = os.path.join(root, folder, 'reconstructed_aligned.stl')
        tmesh = trimesh.load(stl_path, force='mesh')
        graph = Graph(tmesh, k=100)
        _, evecs, _, _ = graph.apply_decomposition()

        jet_cmap = plt.get_cmap('jet')

        eigenmodes_m_sliced = evecs[:, 0]
        eigenmodes_m_n = (eigenmodes_m_sliced - np.min(eigenmodes_m_sliced)) / (np.max(eigenmodes_m_sliced) - np.min(eigenmodes_m_sliced))
        clrs_m = (jet_cmap(eigenmodes_m_n)[:, :3] * 255).astype(np.uint8)
        
        row = i // 9
        col = i % 9
        plotter.subplot(row, col)
        plotter.add_mesh(tmesh, scalars=clrs_m, rgb=True)
        
        i += 1
        if i >= 90:
            break

        plotter.camera_position = [
                            (-1, 0, 0), 
                            (0, 0, 0), 
                            (0, 0, 1)   
        ]
        plotter.reset_camera()


plotter.show()
# Out:
# Widget(value='<iframe src="http://localhost:35307/index.html?ui=P_0x7fd1385e8dc0_12&reconnect=auto" class="pyv…

# %%
# part of code where tibor checks for corresponding eigenvectors, check that

# %%
import os
import numpy as np
import h5py
import pyvista as pv
import trimesh
from matplotlib import pyplot as plt

# %run '../toothForge/src/Graph.py'

data_path = '../toothForge/data/laplace/88-brains'

plotter = pv.Plotter(shape=(1, 2), window_size=(1000, 1200))
i = 0

cases = [
    "sub-017_species-Saimiri+sciureus_hemi-L",
    "sub-018_species-Gorilla+beringei_hemi-L"
]

for root, dirs, files in os.walk(data_path):
    for folder in sorted(dirs):
        
        if folder not in cases:
            continue
 
        stl_path = os.path.join(root, folder, 'reconstructed_aligned.stl')
        tmesh = trimesh.load(stl_path, force='mesh')
        graph = Graph(tmesh, k=100)
        _, evecs, _, _ = graph.apply_decomposition()

        jet_cmap = plt.get_cmap('jet')

        eigenmodes_m_sliced = evecs[:, 0]
        eigenmodes_m_n = (eigenmodes_m_sliced - np.min(eigenmodes_m_sliced)) / (np.max(eigenmodes_m_sliced) - np.min(eigenmodes_m_sliced))
        clrs_m = (jet_cmap(eigenmodes_m_n)[:, :3] * 255).astype(np.uint8)
        
        row = i // 2
        col = i % 2
        plotter.subplot(row, col)
        plotter.add_mesh(tmesh, scalars=clrs_m, rgb=True)       
        i += 1


        plotter.camera_position = [
                            (-1, 0, 0), 
                            (0, 0, 0), 
                            (0, 0, 1)   
        ]
        plotter.reset_camera()


plotter.show()
# Out:
# Widget(value='<iframe src="http://localhost:35307/index.html?ui=P_0x7fd0db5f1880_18&reconnect=auto" class="pyv…

# %%
import os
import numpy as np
import h5py
import pyvista as pv
import trimesh
from matplotlib import pyplot as plt

# %run '../toothForge/src/Graph.py'

data_path = '../toothForge/data/laplace/88-brains'

plotter = pv.Plotter(shape=(1, 2), window_size=(1000, 1200))
i = 0

cases = [
    "sub-017_species-Saimiri+sciureus_hemi-L",
    "sub-018_species-Gorilla+beringei_hemi-L"
]

for root, dirs, files in os.walk(data_path):
    for folder in sorted(dirs):
        
        if folder not in cases:
            continue
 
        stl_path = os.path.join(root, folder, 'reconstructed_aligned.stl')
        tmesh = trimesh.load(stl_path, force='mesh')
        graph = Graph(tmesh, k=100)
        _, evecs, _, _ = graph.apply_decomposition()

        jet_cmap = plt.get_cmap('jet')

        eigenmodes_m_sliced = evecs[:, 1]
        eigenmodes_m_n = (eigenmodes_m_sliced - np.min(eigenmodes_m_sliced)) / (np.max(eigenmodes_m_sliced) - np.min(eigenmodes_m_sliced))
        clrs_m = (jet_cmap(eigenmodes_m_n)[:, :3] * 255).astype(np.uint8)
        
        row = i // 2
        col = i % 2
        plotter.subplot(row, col)
        plotter.add_mesh(tmesh, scalars=clrs_m, rgb=True)       
        i += 1


        plotter.camera_position = [
                            (-1, 0, 0), 
                            (0, 0, 0), 
                            (0, 0, 1)   
        ]
        plotter.reset_camera()


plotter.show()
# Out:
# Widget(value='<iframe src="http://localhost:35307/index.html?ui=P_0x7fd08a6785b0_17&reconnect=auto" class="pyv…

# %%
import os
import numpy as np
import h5py
import pyvista as pv
import trimesh
from matplotlib import pyplot as plt



data_path = '../toothForge/data/laplace/88-brains'

plotter = pv.Plotter(shape=(1, 2), window_size=(1000, 1200))
i = 0

cases = [
    "sub-017_species-Saimiri+sciureus_hemi-L",
    "sub-018_species-Gorilla+beringei_hemi-L"
]

for root, dirs, files in os.walk(data_path):
    for folder in sorted(dirs):
        
        if folder not in cases:
            continue
 
        stl_path = os.path.join(root, folder, 'reconstructed_aligned.stl')
        tmesh = trimesh.load(stl_path, force='mesh')
        graph = Graph(tmesh, k=100)
        _, evecs, _, _ = graph.apply_decomposition()

        jet_cmap = plt.get_cmap('jet')

        eigenmodes_m_sliced = evecs[:, 2]
        eigenmodes_m_n = (eigenmodes_m_sliced - np.min(eigenmodes_m_sliced)) / (np.max(eigenmodes_m_sliced) - np.min(eigenmodes_m_sliced))
        clrs_m = (jet_cmap(eigenmodes_m_n)[:, :3] * 255).astype(np.uint8)
        
        row = i // 2
        col = i % 2
        plotter.subplot(row, col)
        plotter.add_mesh(tmesh, scalars=clrs_m, rgb=True)       
        i += 1


        plotter.camera_position = [
                            (-1, 0, 0), 
                            (0, 0, 0), 
                            (0, 0, 1)   
        ]
        plotter.reset_camera()


plotter.show()
# Out:
# Widget(value='<iframe src="http://localhost:35307/index.html?ui=P_0x7fd0a4e08400_16&reconnect=auto" class="pyv…

# %%
# %run '../toothForge/src/Graph.py'
# %run '../toothForge/src/SpectralMesh.py'

# %%
al = "../toothForge/data/laplace/88-brains/sub-017_species-Saimiri+sciureus_hemi-L/reconstructed_aligned.stl"
un = "../toothForge/data/laplace/88-brains/sub-018_species-Gorilla+beringei_hemi-L/reconstructed_aligned.stl"
tmesh_1 = trimesh.load(al, force='mesh')
mesh_1 = SpectralMesh(tmesh_1, k=100)
mesh_1.visualize_shape_eigenmodes([0, 1, 2, 3, 4, 5, 6, 7])

tmesh_2 = trimesh.load(un, force='mesh')
mesh_2 = SpectralMesh(tmesh_2, k=100)
mesh_2.visualize_shape_eigenmodes([0, 1, 2, 3, 4, 5, 6, 7])
# Out:
# Loaded mesh with 10187 vertices and 20370 faces.
# Widget(value='<iframe src="http://localhost:35307/index.html?ui=P_0x7fd0a023f1f0_19&reconnect=auto" class="pyv…
# Loaded mesh with 10187 vertices and 20370 faces.
# Widget(value='<iframe src="http://localhost:35307/index.html?ui=P_0x7fd09c3d7550_20&reconnect=auto" class="pyv…

# %%
al = "../toothForge/data/laplace/88-brains/sub-025_species-Cercocebus+atys_hemi-L/reconstructed_aligned.stl"
un = "../toothForge/data/laplace/88-brains/sub-026_species-Lophocebus+albigena_hemi-L/reconstructed_aligned.stl"
tmesh_1 = trimesh.load(al, force='mesh')
mesh_1 = SpectralMesh(tmesh_1, k=100)
mesh_1.visualize_shape_eigenmodes([0, 1, 2, 3, 4, 5, 6, 7])

tmesh_2 = trimesh.load(un, force='mesh')
mesh_2 = SpectralMesh(tmesh_2, k=100)
mesh_2.visualize_shape_eigenmodes([0, 1, 2, 3, 4, 5, 6, 7])
# Out:
# Loaded mesh with 10187 vertices and 20370 faces.
# Widget(value='<iframe src="http://localhost:35307/index.html?ui=P_0x7fd0a01aa250_21&reconnect=auto" class="pyv…
# Loaded mesh with 10187 vertices and 20370 faces.
# Widget(value='<iframe src="http://localhost:35307/index.html?ui=P_0x7fd09c97deb0_22&reconnect=auto" class="pyv…

# %% [markdown]
# Interpolating aligned and unaligned brain. If the interpolation is not smooth and the whole interpolated reconstructed shape flips, then it is due to the fact that the alignment might just align the first eigenvectors badly. But because fue to symmetry, it looks fine in the math.

# %%
# interpolation of unaligned ones with template

import os
import numpy as np
import h5py
import pyvista as pv
import trimesh
from matplotlib import pyplot as plt



data_path = '../toothForge/data/laplace/88-brains'

plotter = pv.Plotter(shape=(10, 9), window_size=(1000, 1200))
i = 0

cases = [
    "sub-017_species-Saimiri+sciureus_hemi-L",
    "sub-018_species-Gorilla+beringei_hemi-L"
]

for root, dirs, files in os.walk(data_path):
    for folder in sorted(dirs):
        
        #if folder not in cases:
        #    continue
 
        stl_path = os.path.join(root, folder, 'reconstructed_interp.stl')
        tmesh = trimesh.load(stl_path, force='mesh')
        #graph = Graph(tmesh, k=100)
        #_, evecs, _, _ = graph.apply_decomposition()

        #jet_cmap = plt.get_cmap('jet')

        #eigenmodes_m_sliced = evecs[:, 2]
        #eigenmodes_m_n = (eigenmodes_m_sliced - np.min(eigenmodes_m_sliced)) / (np.max(eigenmodes_m_sliced) - np.min(eigenmodes_m_sliced))
        #clrs_m = (jet_cmap(eigenmodes_m_n)[:, :3] * 255).astype(np.uint8)
        
        row = i // 9
        col = i % 9
        plotter.subplot(row, col)
        plotter.add_mesh(tmesh)       
        i += 1


        plotter.camera_position = [
                            (-1, 0, 0), 
                            (0, 0, 0), 
                            (0, 0, 1)   
        ]
        plotter.reset_camera()


plotter.show()
# Out:
# Widget(value='<iframe src="http://localhost:35307/index.html?ui=P_0x7fd095b28df0_28&reconnect=auto" class="pyv…

# %% [markdown]
# **Comparison**

# %% [markdown]
# <table>
#   <tr>
#     <td><img src="attachment:3b8007d2-665b-4ef5-ada0-06a889b0a9a1.jpeg" width="600"/></td>
#     <td><img src="attachment:0471fb5e-5ef0-49b8-932b-1dfcb9906a4d.png" width="600"/></td>
#   </tr>
# </table>

# %%
import os
import numpy as np
import h5py
import pyvista as pv
import trimesh
from matplotlib import pyplot as plt

# %run '../toothForge/src/Graph.py'

data_path = '../toothForge/data/hungarian/e1'

plotter = pv.Plotter(shape=(10, 9), window_size=(1000, 1200))
i = 0

for root, dirs, files in os.walk(data_path):
    for folder in sorted(dirs):
        
        stl_path = os.path.join(root, folder, 'reconstructed_aligned.stl')
        tmesh = trimesh.load(stl_path, force='mesh')
        graph = Graph(tmesh, k=100)
        _, evecs, _, _ = graph.apply_decomposition()

        jet_cmap = plt.get_cmap('jet')

        eigenmodes_m_sliced = evecs[:, 0]
        eigenmodes_m_n = (eigenmodes_m_sliced - np.min(eigenmodes_m_sliced)) / (np.max(eigenmodes_m_sliced) - np.min(eigenmodes_m_sliced))
        clrs_m = (jet_cmap(eigenmodes_m_n)[:, :3] * 255).astype(np.uint8)
        
        row = i // 9
        col = i % 9
        plotter.subplot(row, col)
        plotter.add_mesh(tmesh, scalars=clrs_m, rgb=True)
        
        i += 1
        if i >= 90:
            break

        plotter.camera_position = [
                            (-1, 0, 0), 
                            (0, 0, 0), 
                            (0, 0, 1)   
        ]
        plotter.reset_camera()


plotter.show()
# Out:
# Widget(value='<iframe src="http://localhost:35307/index.html?ui=P_0x7fd09c59af10_32&reconnect=auto" class="pyv…

# %%
import os
import numpy as np
import h5py
import pyvista as pv
import trimesh
from matplotlib import pyplot as plt

# %run '../toothForge/src/Graph.py'

data_path = '../toothForge/data/hungarian/e2'

plotter = pv.Plotter(shape=(10, 9), window_size=(1000, 1200))
i = 0

for root, dirs, files in os.walk(data_path):
    for folder in sorted(dirs):
        
        stl_path = os.path.join(root, folder, 'reconstructed_aligned.stl')
        tmesh = trimesh.load(stl_path, force='mesh')
        graph = Graph(tmesh, k=100)
        _, evecs, _, _ = graph.apply_decomposition()

        jet_cmap = plt.get_cmap('jet')

        eigenmodes_m_sliced = evecs[:, 0]
        eigenmodes_m_n = (eigenmodes_m_sliced - np.min(eigenmodes_m_sliced)) / (np.max(eigenmodes_m_sliced) - np.min(eigenmodes_m_sliced))
        clrs_m = (jet_cmap(eigenmodes_m_n)[:, :3] * 255).astype(np.uint8)
        
        row = i // 9
        col = i % 9
        plotter.subplot(row, col)
        plotter.add_mesh(tmesh, scalars=clrs_m, rgb=True)
        
        i += 1
        if i >= 90:
            break

        plotter.camera_position = [
                            (-1, 0, 0), 
                            (0, 0, 0), 
                            (0, 0, 1)   
        ]
        plotter.reset_camera()


plotter.show()

# %%
import trimesh

al = "../toothForge/data/hungarian/e2/sub-018_species-Gorilla+beringei_hemi-L/reconstructed_aligned.stl"
tmesh_1 = trimesh.load(al, force='mesh')
mesh_1 = SpectralMesh(tmesh_1, k=100)
mesh_1.visualize_shape_eigenmodes([0, 1, 2, 3, 4, 5, 6, 7])
# Out:
# Loaded mesh with 10187 vertices and 20370 faces.
# Widget(value='<iframe src="http://localhost:44477/index.html?ui=P_0x7fd9fcefed90_1&reconnect=auto" class="pyvi…

# %%
import os
import numpy as np
import h5py
import pyvista as pv
import trimesh
from matplotlib import pyplot as plt

# %run '../toothForge/src/Graph.py'

data_path = '../toothForge/data/hungarian/e2'

plotter = pv.Plotter(shape=(10, 9), window_size=(1000, 1200))
i = 0

for root, dirs, files in os.walk(data_path):
    for folder in sorted(dirs):
        
        stl_path = os.path.join(root, folder, 'reconstructed_aligned.stl')
        tmesh = trimesh.load(stl_path, force='mesh')
        graph = Graph(tmesh, k=100)
        _, evecs, _, _ = graph.apply_decomposition()

        jet_cmap = plt.get_cmap('jet')

        eigenmodes_m_sliced = evecs[:, 0]
        eigenmodes_m_n = (eigenmodes_m_sliced - np.min(eigenmodes_m_sliced)) / (np.max(eigenmodes_m_sliced) - np.min(eigenmodes_m_sliced))
        clrs_m = (jet_cmap(eigenmodes_m_n)[:, :3] * 255).astype(np.uint8)
        
        row = i // 9
        col = i % 9
        plotter.subplot(row, col)
        plotter.add_mesh(tmesh, scalars=clrs_m, rgb=True)
        
        i += 1
        if i >= 90:
            break

        plotter.camera_position = [
                            (-1, 0, 0), 
                            (0, 0, 0), 
                            (0, 0, 1)   
        ]
        plotter.reset_camera()


plotter.show()
# Out:
# Widget(value='<iframe src="http://localhost:44477/index.html?ui=P_0x7fd9efb51730_2&reconnect=auto" class="pyvi…

# %%
import os
import numpy as np
import h5py
import pyvista as pv
import trimesh
from matplotlib import pyplot as plt

# %run '../toothForge/src/Graph.py'

data_path = '../toothForge/data/hungarian/e3-nocheckflipsigns'

plotter = pv.Plotter(shape=(10, 9), window_size=(1000, 1200))
i = 0

for root, dirs, files in os.walk(data_path):
    for folder in sorted(dirs):
        
        stl_path = os.path.join(root, folder, 'reconstructed_aligned.stl')
        tmesh = trimesh.load(stl_path, force='mesh')
        graph = Graph(tmesh, k=100)
        _, evecs, _, _ = graph.apply_decomposition()

        jet_cmap = plt.get_cmap('jet')

        eigenmodes_m_sliced = evecs[:, 0]
        eigenmodes_m_n = (eigenmodes_m_sliced - np.min(eigenmodes_m_sliced)) / (np.max(eigenmodes_m_sliced) - np.min(eigenmodes_m_sliced))
        clrs_m = (jet_cmap(eigenmodes_m_n)[:, :3] * 255).astype(np.uint8)
        
        row = i // 9
        col = i % 9
        plotter.subplot(row, col)
        plotter.add_mesh(tmesh, scalars=clrs_m, rgb=True)
        
        i += 1
        if i >= 90:
            break

        plotter.camera_position = [
                            (-1, 0, 0), 
                            (0, 0, 0), 
                            (0, 0, 1)   
        ]
        plotter.reset_camera()


plotter.show()
# Out:
# Widget(value='<iframe src="http://localhost:44477/index.html?ui=P_0x7fda02d09670_3&reconnect=auto" class="pyvi…

# %%
import os
import numpy as np
import h5py
import pyvista as pv
import trimesh
from matplotlib import pyplot as plt

# %run '../toothForge/src/Graph.py'

data_path = '../toothForge/data/hungarian/e4'

plotter = pv.Plotter(shape=(10, 9), window_size=(1000, 1200))
i = 0

for root, dirs, files in os.walk(data_path):
    for folder in sorted(dirs):
        
        stl_path = os.path.join(root, folder, 'reconstructed_aligned.stl')
        tmesh = trimesh.load(stl_path, force='mesh')
        graph = Graph(tmesh, k=100)
        _, evecs, _, _ = graph.apply_decomposition()

        jet_cmap = plt.get_cmap('jet')

        eigenmodes_m_sliced = evecs[:, 0]
        eigenmodes_m_n = (eigenmodes_m_sliced - np.min(eigenmodes_m_sliced)) / (np.max(eigenmodes_m_sliced) - np.min(eigenmodes_m_sliced))
        clrs_m = (jet_cmap(eigenmodes_m_n)[:, :3] * 255).astype(np.uint8)
        
        row = i // 9
        col = i % 9
        plotter.subplot(row, col)
        plotter.add_mesh(tmesh, scalars=clrs_m, rgb=True)
        
        i += 1
        if i >= 90:
            break

        plotter.camera_position = [
                            (-1, 0, 0), 
                            (0, 0, 0), 
                            (0, 0, 1)   
        ]
        plotter.reset_camera()


plotter.show()
# Out:
# Widget(value='<iframe src="http://localhost:44477/index.html?ui=P_0x7fd9ef32b7f0_4&reconnect=auto" class="pyvi…

# %%
import os
import numpy as np
import h5py
import pyvista as pv
import trimesh
from matplotlib import pyplot as plt

# %run '../toothForge/src/Graph.py'

data_path = '../toothForge/data/hungarian/e5'

plotter = pv.Plotter(shape=(10, 9), window_size=(1000, 1200))
i = 0

for root, dirs, files in os.walk(data_path):
    for folder in sorted(dirs):
        
        stl_path = os.path.join(root, folder, 'reconstructed_aligned.stl')
        tmesh = trimesh.load(stl_path, force='mesh')
        graph = Graph(tmesh, k=100)
        _, evecs, _, _ = graph.apply_decomposition()

        jet_cmap = plt.get_cmap('jet')

        eigenmodes_m_sliced = evecs[:, 0]
        eigenmodes_m_n = (eigenmodes_m_sliced - np.min(eigenmodes_m_sliced)) / (np.max(eigenmodes_m_sliced) - np.min(eigenmodes_m_sliced))
        clrs_m = (jet_cmap(eigenmodes_m_n)[:, :3] * 255).astype(np.uint8)
        
        row = i // 9
        col = i % 9
        plotter.subplot(row, col)
        plotter.add_mesh(tmesh, scalars=clrs_m, rgb=True)
        
        i += 1

        plotter.camera_position = [
                            (-1, 0, 0), 
                            (0, 0, 0), 
                            (0, 0, 1)   
        ]
        plotter.reset_camera()


plotter.show()
# Out:
# Widget(value='<iframe src="http://localhost:44477/index.html?ui=P_0x7fd9fcefe760_5&reconnect=auto" class="pyvi…

# %%
import os
import numpy as np
import h5py
import pyvista as pv
import trimesh
from matplotlib import pyplot as plt

# %run '../toothForge/src/Graph.py'

data_path = '../toothForge/data/hungarian/e6'

plotter = pv.Plotter(shape=(10, 9), window_size=(1000, 1200))
i = 0

for root, dirs, files in os.walk(data_path):
    for folder in sorted(dirs):
        
        stl_path = os.path.join(root, folder, 'reconstructed_aligned.stl')
        tmesh = trimesh.load(stl_path, force='mesh')
        graph = Graph(tmesh, k=100)
        _, evecs, _, _ = graph.apply_decomposition()

        jet_cmap = plt.get_cmap('jet')

        eigenmodes_m_sliced = evecs[:, 0]
        eigenmodes_m_n = (eigenmodes_m_sliced - np.min(eigenmodes_m_sliced)) / (np.max(eigenmodes_m_sliced) - np.min(eigenmodes_m_sliced))
        clrs_m = (jet_cmap(eigenmodes_m_n)[:, :3] * 255).astype(np.uint8)
        
        row = i // 9
        col = i % 9
        plotter.subplot(row, col)
        plotter.add_mesh(tmesh, scalars=clrs_m, rgb=True)
        
        i += 1

        plotter.camera_position = [
                            (-1, 0, 0), 
                            (0, 0, 0), 
                            (0, 0, 1)   
        ]
        plotter.reset_camera()


plotter.show()
# Out:
# Widget(value='<iframe src="http://localhost:44477/index.html?ui=P_0x7fd9e46cb4c0_6&reconnect=auto" class="pyvi…

# %%
import trimesh

al = "../toothForge/data/hungarian/e6/sub-018_species-Gorilla+beringei_hemi-L/reconstructed_aligned.stl"
tmesh_1 = trimesh.load(al, force='mesh')
mesh_1 = SpectralMesh(tmesh_1, k=100)
mesh_1.visualize_shape_eigenmodes([0, 1, 2, 3, 4, 5, 6, 7])
# Out:
# Loaded mesh with 10187 vertices and 20370 faces.
# Widget(value='<iframe src="http://localhost:44477/index.html?ui=P_0x7fd9cd190910_9&reconnect=auto" class="pyvi…

# %%
import os
import numpy as np
import h5py
import pyvista as pv
import trimesh
from matplotlib import pyplot as plt

# %run '../toothForge/src/Graph.py'

data_path = '../toothForge/data/hungarian/e6'

plotter = pv.Plotter(shape=(10, 9), window_size=(1000, 1200))
i = 0

for root, dirs, files in os.walk(data_path):
    for folder in sorted(dirs):
        
        stl_path = os.path.join(root, folder, 'reconstructed_aligned.stl')
        tmesh = trimesh.load(stl_path, force='mesh')
        graph = Graph(tmesh, k=100)
        _, evecs, _, _ = graph.apply_decomposition()

        jet_cmap = plt.get_cmap('jet')

        eigenmodes_m_sliced = evecs[:, 0]
        eigenmodes_m_n = (eigenmodes_m_sliced - np.min(eigenmodes_m_sliced)) / (np.max(eigenmodes_m_sliced) - np.min(eigenmodes_m_sliced))
        clrs_m = (jet_cmap(eigenmodes_m_n)[:, :3] * 255).astype(np.uint8)
        
        row = i // 9
        col = i % 9
        plotter.subplot(row, col)
        plotter.add_mesh(tmesh, scalars=clrs_m, rgb=True)
        
        i += 1

        plotter.camera_position = [
                            (-1, 0, 0), 
                            (0, 0, 0), 
                            (0, 0, 1)   
        ]
        plotter.reset_camera()


plotter.show()
# Out:
# Widget(value='<iframe src="http://localhost:44477/index.html?ui=P_0x7fd9e4734040_12&reconnect=auto" class="pyv…

# %% [markdown]
# ![screenshot(44).png](attachment:eeb6e95d-97eb-4a24-9254-5e15e198e4b7.png)

# %%
import os
import numpy as np
import h5py
import pyvista as pv
import trimesh
from matplotlib import pyplot as plt

# %run '../toothForge/src/Graph.py'

data_path = '../toothForge/data/hungarian/e6'

plotter = pv.Plotter(shape=(10, 9), window_size=(1000, 1200))
i = 0

for root, dirs, files in os.walk(data_path):
    for folder in sorted(dirs):
        
        stl_path = os.path.join(root, folder, 'reconstructed_aligned.stl')
        tmesh = trimesh.load(stl_path, force='mesh')
        graph = Graph(tmesh, k=100)
        _, evecs, _, _ = graph.apply_decomposition()

        jet_cmap = plt.get_cmap('jet')

        eigenmodes_m_sliced = evecs[:, 1]
        eigenmodes_m_n = (eigenmodes_m_sliced - np.min(eigenmodes_m_sliced)) / (np.max(eigenmodes_m_sliced) - np.min(eigenmodes_m_sliced))
        clrs_m = (jet_cmap(eigenmodes_m_n)[:, :3] * 255).astype(np.uint8)
        
        row = i // 9
        col = i % 9
        plotter.subplot(row, col)
        plotter.add_mesh(tmesh, scalars=clrs_m, rgb=True)
        
        i += 1

        plotter.camera_position = [
                            (-1, 0, 0), 
                            (0, 0, 0), 
                            (0, 0, 1)   
        ]
        plotter.reset_camera()


plotter.show()
# Out:
# Widget(value='<iframe src="http://localhost:44477/index.html?ui=P_0x7fd9c1db5d60_19&reconnect=auto" class="pyv…

# %% [markdown]
# ![screenshot(45).png](attachment:94fcb644-f632-41f8-96db-840f0b6c1d1f.png)

# %%
import os
import numpy as np
import h5py
import pyvista as pv
import trimesh
from matplotlib import pyplot as plt

# %run '../toothForge/src/Graph.py'

data_path = '../toothForge/data/hungarian/e6'

plotter = pv.Plotter(shape=(10, 9), window_size=(1000, 1200))
i = 0

for root, dirs, files in os.walk(data_path):
    for folder in sorted(dirs):
        
        stl_path = os.path.join(root, folder, 'reconstructed_aligned.stl')
        tmesh = trimesh.load(stl_path, force='mesh')
        graph = Graph(tmesh, k=100)
        _, evecs, _, _ = graph.apply_decomposition()

        jet_cmap = plt.get_cmap('jet')

        eigenmodes_m_sliced = evecs[:, 3]
        eigenmodes_m_n = (eigenmodes_m_sliced - np.min(eigenmodes_m_sliced)) / (np.max(eigenmodes_m_sliced) - np.min(eigenmodes_m_sliced))
        clrs_m = (jet_cmap(eigenmodes_m_n)[:, :3] * 255).astype(np.uint8)
        
        row = i // 9
        col = i % 9
        plotter.subplot(row, col)
        plotter.add_mesh(tmesh, scalars=clrs_m, rgb=True)
        
        i += 1

        plotter.camera_position = [
                            (-1, 0, 0), 
                            (0, 0, 0), 
                            (0, 0, 1)   
        ]
        plotter.reset_camera()


plotter.show()
# Out:
# Widget(value='<iframe src="http://localhost:44477/index.html?ui=P_0x7fd9cf5dca00_17&reconnect=auto" class="pyv…

# %% [markdown]
# ![screenshot(46).png](attachment:a578ebfc-e0e7-4700-8f13-28b0176dd687.png)

# %%
import os
import numpy as np
import h5py
import pyvista as pv
import trimesh
from matplotlib import pyplot as plt

# %run '../toothForge/src/Graph.py'

data_path = '../toothForge/data/hungarian/e6'

plotter = pv.Plotter(shape=(10, 9), window_size=(1000, 1200))
i = 0

for root, dirs, files in os.walk(data_path):
    for folder in sorted(dirs):
        
        stl_path = os.path.join(root, folder, 'reconstructed_aligned.stl')
        tmesh = trimesh.load(stl_path, force='mesh')
        graph = Graph(tmesh, k=100)
        _, evecs, _, _ = graph.apply_decomposition()

        jet_cmap = plt.get_cmap('jet')

        eigenmodes_m_sliced = evecs[:, 4]
        eigenmodes_m_n = (eigenmodes_m_sliced - np.min(eigenmodes_m_sliced)) / (np.max(eigenmodes_m_sliced) - np.min(eigenmodes_m_sliced))
        clrs_m = (jet_cmap(eigenmodes_m_n)[:, :3] * 255).astype(np.uint8)
        
        row = i // 9
        col = i % 9
        plotter.subplot(row, col)
        plotter.add_mesh(tmesh, scalars=clrs_m, rgb=True)
        
        i += 1

        plotter.camera_position = [
                            (-1, 0, 0), 
                            (0, 0, 0), 
                            (0, 0, 1)   
        ]
        plotter.reset_camera()


plotter.show()
# Out:
# Widget(value='<iframe src="http://localhost:44477/index.html?ui=P_0x7fd9bc6aecd0_18&reconnect=auto" class="pyv…

# %% [markdown]
# ![screenshot(47).png](attachment:6e0f5580-94f7-4669-8dd4-4b1a7b868a9f.png)

# %%
import os
import numpy as np
import h5py
import pyvista as pv
import trimesh
from matplotlib import pyplot as plt

# %run '../toothForge/src/Graph.py'

data_path = '../toothForge/data/hungarian/e7'

plotter = pv.Plotter(shape=(10, 9), window_size=(1000, 1200))
i = 0

for root, dirs, files in os.walk(data_path):
    for folder in sorted(dirs):
        
        stl_path = os.path.join(root, folder, 'reconstructed_aligned.stl')
        tmesh = trimesh.load(stl_path, force='mesh')
        graph = Graph(tmesh, k=100)
        _, evecs, _, _ = graph.apply_decomposition()

        jet_cmap = plt.get_cmap('jet')

        eigenmodes_m_sliced = evecs[:, 0]
        eigenmodes_m_n = (eigenmodes_m_sliced - np.min(eigenmodes_m_sliced)) / (np.max(eigenmodes_m_sliced) - np.min(eigenmodes_m_sliced))
        clrs_m = (jet_cmap(eigenmodes_m_n)[:, :3] * 255).astype(np.uint8)
        
        row = i // 9
        col = i % 9
        plotter.subplot(row, col)
        plotter.add_mesh(tmesh, scalars=clrs_m, rgb=True)
        
        i += 1

        plotter.camera_position = [
                            (-1, 0, 0), 
                            (0, 0, 0), 
                            (0, 0, 1)   
        ]
        plotter.reset_camera()


plotter.show()
# Out:
# Widget(value='<iframe src="http://localhost:44477/index.html?ui=P_0x7fda44b8f5e0_21&reconnect=auto" class="pyv…

# %%
import os
import numpy as np
import h5py
import pyvista as pv
import trimesh
from matplotlib import pyplot as plt

# %run '../toothForge/src/Graph.py'

data_path = '../toothForge/data/hungarian/e8'

plotter = pv.Plotter(shape=(10, 9), window_size=(1000, 1200))
i = 0

for root, dirs, files in os.walk(data_path):
    for folder in sorted(dirs):
        
        stl_path = os.path.join(root, folder, 'reconstructed_aligned.stl')
        tmesh = trimesh.load(stl_path, force='mesh')
        graph = Graph(tmesh, k=100)
        _, evecs, _, _ = graph.apply_decomposition()

        jet_cmap = plt.get_cmap('jet')

        eigenmodes_m_sliced = evecs[:, 4]
        eigenmodes_m_n = (eigenmodes_m_sliced - np.min(eigenmodes_m_sliced)) / (np.max(eigenmodes_m_sliced) - np.min(eigenmodes_m_sliced))
        clrs_m = (jet_cmap(eigenmodes_m_n)[:, :3] * 255).astype(np.uint8)
        
        row = i // 9
        col = i % 9
        plotter.subplot(row, col)
        plotter.add_mesh(tmesh, scalars=clrs_m, rgb=True)
        
        i += 1

        plotter.camera_position = [
                            (-1, 0, 0), 
                            (0, 0, 0), 
                            (0, 0, 1)   
        ]
        plotter.reset_camera()


plotter.show()
# Out:
# Widget(value='<iframe src="http://localhost:44477/index.html?ui=P_0x7fd9cca1ea60_32&reconnect=auto" class="pyv…

# %%
import os
import numpy as np
import h5py
import pyvista as pv
import trimesh
from matplotlib import pyplot as plt

# %run '../toothForge/src/Graph.py'

data_path = '../toothForge/data/no-hungarian/e1'

plotter = pv.Plotter(shape=(10, 9), window_size=(1000, 1200))
i = 0

for root, dirs, files in os.walk(data_path):
    for folder in sorted(dirs):
        
        stl_path = os.path.join(root, folder, 'reconstructed_aligned.stl')
        tmesh = trimesh.load(stl_path, force='mesh')
        graph = Graph(tmesh, k=100)
        _, evecs, _, _ = graph.apply_decomposition()

        jet_cmap = plt.get_cmap('jet')

        eigenmodes_m_sliced = evecs[:, 4]
        eigenmodes_m_n = (eigenmodes_m_sliced - np.min(eigenmodes_m_sliced)) / (np.max(eigenmodes_m_sliced) - np.min(eigenmodes_m_sliced))
        clrs_m = (jet_cmap(eigenmodes_m_n)[:, :3] * 255).astype(np.uint8)
        
        row = i // 9
        col = i % 9
        plotter.subplot(row, col)
        plotter.add_mesh(tmesh, scalars=clrs_m, rgb=True)
        
        i += 1

        plotter.camera_position = [
                            (-1, 0, 0), 
                            (0, 0, 0), 
                            (0, 0, 1)   
        ]
        plotter.reset_camera()


plotter.show()
# Out:
# Widget(value='<iframe src="http://localhost:44477/index.html?ui=P_0x7fd9ca3378e0_28&reconnect=auto" class="pyv…
